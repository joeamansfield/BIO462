# %% [markdown]
# # **Homework 6 - Proteomics**
# The purpose of this homework is to teach you how to identify significantly differential protein abundances and how to identify significant correlation between proteins.
#
# License: This document is open source under [CC BY-ND 4.0](https://en.wikipedia.org/wiki/Creative_Commons_license).

# %% [markdown]
# # **Completing the Assignment**
#
# This notebook is your homework #6. To complete the homework and receive credit, you need to work through all 5 sections. Within each thematic section is a mix of explanatory text cells and code cells. Some code cells have code written for you; some ask you to write code. At the end of each section are 'Practice Problems'. You should write code to answer the questions - following the directions given. Once you are ready to submit your answer, run the submission code block below every question block. If you get a question wrong, fix your code and try again. If you get stumped, ask for a hint using the hint code block below each submission code block. This homework also has several sections of code that might take a few minutes.
#
# Your first step will be to save this notebook as a copy so that you can edit it. (File->Save a copy in Drive).
#
# Have fun.

# %% [markdown]
# # **Learning Outcomes**
# #### Biological
#
# *   Evaluate utility of protein coexpression networks based on agreement with known protein interaction networks.
#
# #### Computational
#
# *   Perform correlation analysis.
# *   Create network visualization.
# *   Access UniProt knowledgebase using API.

# %% [markdown]
# # **Topics and Background Reading**
#
# [Proteomics](https://en.wikipedia.org/wiki/Proteomics) is the comprehensive measurement of protein abundance. Proteins are the dominant functional molecule in cellular life. Proteins are the structural support of a cell (i.e. the cytoskeleton); proteins perform metabolic conversion and control energy flow in a cell; and proteins sense the environment and generate signals to trigger a response to the environment.
#
# In our cancer datasets, we typically get an abundance measurement for more than 10,000 proteins in each tumor sample. The majority of proteomics measurements are obtained via [mass spectrometry](https://en.wikipedia.org/wiki/Mass_spectrometry). In our dataset, the quantitative measurement is a relative abundance, meaning we ask the question, "Does a sample have more/less of a protein than the 'average' sample?" More detail on this is given below. First, let's read some manuscripts about the data generation and statistical challenges in the field.
#
# * [Aebersold 2003](https://pubmed.ncbi.nlm.nih.gov/12634793/)
# * [Nesvizhskii 2005](https://pubmed.ncbi.nlm.nih.gov/16009968/)
# * [Piazza 2018](https://pubmed.ncbi.nlm.nih.gov/29307493/)
# * [Dou 2020](https://pubmed.ncbi.nlm.nih.gov/32059776/)

# %% [markdown]
# # Part 1. Setup

# %% [markdown]
# First we need to install and import the cptac and biograder packages along with a few other packages.

# %%
# !pip install cptac
# !pip install biograder

# %% [markdown]
# We will be working with three similar cancer cohorts in this homework. Examples will be shown to you with the lung adenocarcinoma (LUAD) cohort. Afterwards some questions will ask you to perform analyses on the lung squamous cell carcinoma (LSCC) cohort and the head/neck squamous cell carcinoma (HNSCC) cohort for comparision.

# %%
#Be patient, this may take a few minutes depending on your internet connection.
import cptac

cptac.download('luad')
lu = cptac.Luad()
cptac.download('lscc')
ls = cptac.Lscc()
cptac.download('hnscc')
hn = cptac.Hnscc()

# %% [markdown]
# We have to import a couple more packages that we will used throughout the homework.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import statistics

# %% [markdown]
# Lastly, we need to get the homework autograder. This will have the same steps of server install, importing and object creation.

# %%
import biograder
#The proteomics homework is #6
biograder.download("bio462_hw6")
myID = "joeaman" #Your student id, or 'temp'
hw = biograder.bio462_hw6(student_id = myID) #Instantiate the homework grader object.

# %% [markdown]
# For this lesson we need to get the joined clinical and proteomics dataframe for tumor and normal tissue from the LUAD cohort.

# %%
import cptac.utils as ut

lu_clin_prot = lu.join_metadata_to_omics(metadata_df_name='clinical',
  omics_df_name='proteomics',
  metadata_cols = ["Sample_Tumor_Normal"])
#Some functions require that we drop the Database_ID column.
luad_no_id = ut.reduce_multiindex(df=lu_clin_prot, levels_to_drop="Database_ID")
luad_no_id

# %% [markdown]
# # Part 2. Protein Correlation

# %% [markdown]
# In HW5 we learned about differential expression, what transcripts are changing between conditions. In this lesson we learn about how to assess which proteins are changing in a similar way. This is sometimes called co-expression analysis. Today we'll call this correlation, because that is evocative of the statistical test.

# %% [markdown]
# Linear regression can help us determine how a change in abundance for one protein might predict the abundance of another protein.
# We can create a scatterplot with seaborn in order to measure the linear regression between two ribosomal proteins known as RPS13 and RPS11.

# %%
from scipy.stats import linregress
tumor_type = lu_clin_prot.loc[lu_clin_prot['Sample_Tumor_Normal'] == 'Tumor']
plot = sns.regplot(x=tumor_type['RPS13_proteomics'], y=tumor_type['RPS11_proteomics'])
plt.xlabel('RPS13',fontsize=16)
plt.ylabel('RPS11',fontsize=16)
plot_results = linregress(plot.get_lines()[0].get_xdata(),plot.get_lines()[0].get_ydata())
print('slope =', round(plot_results[0],5),'y-intercept =', round(plot_results[1],5))
# Out:
# slope = 0.80904 y-intercept = 0.30342

# %% [markdown]
# Linear regression is a way to build a prediction formula, given proteinX I can predit the value of proteinY. That comes from the slope and y-intercept you see printed above.

# %% [markdown]
# Correlation is not a prediction method, but just a measure of how similar the abundance patterns of the two proteins is. This is done using pearsonr() from the scipy.stats package which uses the [Pearson method](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient). In the code below, we call the function and print out both the correlation coefficient and p-value.

# %%
corr,pval = stats.pearsonr(luad_no_id['RPS13_proteomics'], luad_no_id['RPS11_proteomics'])
print("Correlation:", corr, "\nP-value:", pval)
# Out:
# Correlation: 0.8381934491836718
# P-value: 6.110973880316397e-57

# %% [markdown]
# We can see that the correlation coefficient is 0.83 which indicates a strong positive linear correlation between RPS13 and RPS11. The p-value of 6.11e-57 tells us that this correlation is statistically significant. These two ribosomal proteins physically interact and make up part of the small subunit of a ribosome. So it makes sense that their protein abundance would be highly correlated.
#
# Now you try. Calculate the correlation coefficients for two other genes: PTEN and CDC27.

# %%
#Get the correlation coefficient for PTEN and CDC27.
##  Your code here  ##
corr,pval = stats.pearsonr(luad_no_id['PTEN_proteomics'], luad_no_id['CDC27_proteomics'])
print("Correlation:", corr, "\nP-value:", pval)
# Out:
# Correlation: -0.30088326884399524
# P-value: 8.662166135652195e-06

# %% [markdown]
# As you can see, PTEN and CDC27 have a negative correlation coefficient and a p-value < 0.05. Think about what that means for their interaction.

# %% [markdown]
# We want to get the correlation coefficient between every protein within the entire proteomics dataframe. To do this we use the .corr() function. As you investigate this, note that the resulting dataframe only has correlation coefficients and not p-values. The .corr() function only computes that; it does not compute p-values.

# %%
#Be patient, this may take a minute depending on your internet connection.
lu_proteomics = lu.get_proteomics()
lu_prot_no_id = ut.reduce_multiindex(df=lu_proteomics, levels_to_drop="Database_ID")
lu_correlation = lu_prot_no_id.corr(method='pearson')
lu_correlation.head(50)
# Out:
# cptac warning: Due to dropping the specified levels, dataframe now has 745 duplicated column headers. (/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py, line 3)
# Name          A1BG       A2M      AAAS      AACS     AADAC     AADAT  \
# Name
# A1BG      1.000000  0.909624 -0.041762 -0.592925  0.369252  0.417703
# A2M       0.909624  1.000000 -0.043899 -0.617693  0.387220  0.426801
# AAAS     -0.041762 -0.043899  1.000000  0.148053 -0.142676  0.088912
# AACS     -0.592925 -0.617693  0.148053  1.000000 -0.334582 -0.165616
# AADAC     0.369252  0.387220 -0.142676 -0.334582  1.000000  0.042512
# AADAT     0.417703  0.426801  0.088912 -0.165616  0.042512  1.000000
# AAED1     0.773142  0.707464 -0.043632 -0.469641  0.283612  0.427640
# AAGAB    -0.410624 -0.415950  0.184647  0.430621 -0.380968  0.052249
# AAMDC     0.424745  0.402483 -0.109814 -0.368196  0.318765  0.128306
# AAMP     -0.435489 -0.415259  0.096922  0.271030 -0.150389 -0.264725
# AAR2     -0.106941 -0.123143  0.262436  0.178110 -0.059566 -0.046738
# AARS     -0.600096 -0.630004  0.147704  0.587671 -0.363294 -0.242648
# AARS2    -0.237121 -0.245834  0.327436  0.283093 -0.214650  0.221627
# AARSD1   -0.383502 -0.429598  0.285388  0.422829 -0.399525 -0.381200
# AASDHPPT -0.446138 -0.462474  0.132836  0.323806 -0.200334 -0.264646
# AASS      0.192306  0.181298 -0.007863  0.042983  0.014351  0.257293
# AATF     -0.568443 -0.568735  0.306886  0.549171 -0.443642 -0.162362
# AATK      0.350976  0.375255 -0.277770 -0.357649  0.246449  0.196567
# ABAT     -0.178682 -0.135570  0.100068  0.197471 -0.048785  0.112605
# ABCA1     0.426567  0.389114  0.003469 -0.217736  0.055609  0.196878
# ABCA12    0.571946  0.554906 -0.012353 -0.366521  0.296396  0.387235
# ABCA13    0.273329  0.260759  0.036532 -0.207220  0.110604  0.397127
# ABCA2    -0.186440 -0.192987 -0.120390  0.140465 -0.075728 -0.114203
# ABCA3     0.694118  0.717202 -0.156523 -0.538807  0.448735  0.303950
# ABCA6     0.760906  0.778845 -0.099421 -0.570635  0.441596  0.359958
# ABCA7    -0.239459 -0.299490  0.170953  0.195922 -0.219486  0.044480
# ABCA8     0.799442  0.808372 -0.129050 -0.661979  0.523272  0.375572
# ABCB1     0.599342  0.572928 -0.200708 -0.419934  0.375658  0.320585
# ABCB10    0.171371  0.173530  0.071973  0.038159  0.168346  0.139406
# ABCB5     0.105214  0.083469  0.001193  0.035993  0.036776 -0.048533
# ABCB6     0.218405  0.238715  0.082867 -0.135237  0.080514  0.248713
# ABCB7    -0.246064 -0.218752  0.253938  0.362132 -0.162991  0.121782
# ABCB8    -0.015211  0.010601  0.239109  0.112220  0.030510  0.254962
# ABCC1    -0.149097 -0.111936  0.081644  0.109510 -0.020602  0.110013
# ABCC10    0.246049  0.231988  0.056837 -0.058878  0.223399  0.459854
# ABCC2     0.346854  0.322884  0.052670 -0.204351 -0.007373 -0.013440
# ABCC3    -0.472257 -0.440993  0.071096  0.334058 -0.180772 -0.133605
# ABCC4     0.139382  0.177650  0.007013 -0.025043  0.101832  0.112771
# ABCC4     0.265966  0.291935 -0.026467 -0.067437  0.275499  0.179206
# ABCC5    -0.053326 -0.050281  0.130273  0.106360  0.010489  0.099284
# ABCC6     0.317307  0.324774  0.006293 -0.231177  0.187538  0.159838
# ABCC8     0.494506  0.487376 -0.020680 -0.293672  0.302217  0.167825
# ABCD1    -0.186270 -0.226157  0.084729  0.227809 -0.222166  0.030357
# ABCD3    -0.340554 -0.326875  0.028481  0.321961 -0.036271 -0.129816
# ABCD4    -0.114139 -0.086630  0.034740  0.171016 -0.066539 -0.049664
# ABCE1    -0.561982 -0.559839  0.186708  0.403237 -0.494168 -0.319576
# ABCF1    -0.654286 -0.649752  0.260610  0.518926 -0.406007 -0.358402
# ABCF2    -0.609974 -0.637771  0.245836  0.513410 -0.489216 -0.359933
# ABCF3    -0.571529 -0.557390  0.093436  0.440668 -0.411697 -0.376055
# ABCG1     0.133252  0.102993 -0.191804  0.092467  0.237954  0.009351
#
# Name         AAED1     AAGAB     AAMDC      AAMP  ...   ZSCAN31    ZSWIM9  \
# Name                                              ...
# A1BG      0.773142 -0.410624  0.424745 -0.435489  ... -0.146061  0.617311
# A2M       0.707464 -0.415950  0.402483 -0.415259  ... -0.134065  0.622711
# AAAS     -0.043632  0.184647 -0.109814  0.096922  ...  0.081381 -0.127371
# AACS     -0.469641  0.430621 -0.368196  0.271030  ...  0.083999 -0.397749
# AADAC     0.283612 -0.380968  0.318765 -0.150389  ... -0.031138  0.297189
# AADAT     0.427640  0.052249  0.128306 -0.264725  ...  0.090433  0.341386
# AAED1     1.000000 -0.304319  0.457982 -0.371811  ... -0.122219  0.503085
# AAGAB    -0.304319  1.000000 -0.296679  0.287403  ...  0.164340 -0.326980
# AAMDC     0.457982 -0.296679  1.000000 -0.250569  ... -0.047572  0.380483
# AAMP     -0.371811  0.287403 -0.250569  1.000000  ...  0.206308 -0.263818
# AAR2     -0.082717  0.222742  0.009541  0.134078  ...  0.041379 -0.209849
# AARS     -0.495174  0.498690 -0.366073  0.317702  ...  0.053720 -0.523235
# AARS2    -0.189971  0.375212 -0.179291  0.154094  ...  0.054026 -0.137075
# AARSD1   -0.316236  0.422288 -0.211271  0.192503  ...  0.064255 -0.396750
# AASDHPPT -0.254054  0.403960 -0.155081  0.277516  ... -0.070940 -0.401760
# AASS      0.202671 -0.077089 -0.029225 -0.117995  ...  0.058038  0.064158
# AATF     -0.527198  0.523057 -0.393392  0.264976  ... -0.032025 -0.581837
# AATK      0.311044 -0.256775  0.245934 -0.123919  ...  0.142949  0.461263
# ABAT     -0.176047 -0.041462 -0.175416  0.145827  ...  0.185733  0.023709
# ABCA1     0.483059 -0.138999  0.145881 -0.265065  ... -0.280870  0.262583
# ABCA12    0.540917 -0.267091  0.274344 -0.181124  ...  0.077411  0.611972
# ABCA13    0.297924 -0.085608  0.286730 -0.069162  ... -0.091010  0.238724
# ABCA2    -0.099799 -0.028355 -0.123593  0.076164  ...  0.141130 -0.011369
# ABCA3     0.574847 -0.518090  0.361417 -0.276331  ... -0.098007  0.596857
# ABCA6     0.666640 -0.417284  0.406784 -0.315412  ... -0.099467  0.667690
# ABCA7    -0.154658  0.114054 -0.183151 -0.119822  ... -0.092833 -0.242149
# ABCA8     0.616410 -0.535582  0.503469 -0.338893  ... -0.071608  0.634246
# ABCB1     0.503005 -0.383034  0.336310 -0.288631  ... -0.086451  0.407395
# ABCB10    0.002135  0.001874 -0.055549 -0.162315  ... -0.064908  0.147457
# ABCB5     0.025784  0.078376 -0.050121 -0.087719  ... -0.092985 -0.029161
# ABCB6     0.208081 -0.083308  0.017660 -0.153674  ...  0.076183  0.204010
# ABCB7    -0.208926  0.280734 -0.240082  0.037912  ...  0.050922 -0.182276
# ABCB8    -0.005041  0.172661 -0.023666 -0.054446  ...  0.079815  0.012773
# ABCC1    -0.137714  0.215300 -0.156245 -0.014866  ...  0.137741 -0.069502
# ABCC10    0.094331 -0.075245  0.187968 -0.211576  ...  0.215984  0.257971
# ABCC2     0.339438  0.030794  0.124188 -0.068193  ...  0.093640  0.128341
# ABCC3    -0.498571  0.234224 -0.239687  0.183346  ...  0.162479 -0.340159
# ABCC4    -0.094417 -0.256161  0.020143 -0.339172  ... -0.055654  0.152175
# ABCC4     0.096910 -0.215706  0.073996 -0.275493  ...  0.047524  0.218593
# ABCC5    -0.092361  0.100574 -0.153370 -0.009559  ... -0.036063  0.073161
# ABCC6     0.195488 -0.295614  0.160288 -0.193497  ...  0.177152  0.351722
# ABCC8     0.500015 -0.211167  0.106858 -0.176818  ...  0.002387  0.217910
# ABCD1    -0.154390  0.251256 -0.196658  0.096950  ...  0.181514 -0.121188
# ABCD3    -0.418716  0.059040 -0.193420  0.121250  ...  0.153287 -0.173142
# ABCD4    -0.193223 -0.018626  0.012126  0.010531  ...  0.136092 -0.086486
# ABCE1    -0.444168  0.522907 -0.400623  0.259409  ... -0.035908 -0.496574
# ABCF1    -0.545237  0.444760 -0.370280  0.378625  ...  0.035524 -0.581574
# ABCF2    -0.445750  0.502880 -0.359662  0.277451  ...  0.019268 -0.594847
# ABCF3    -0.476858  0.422246 -0.308465  0.392847  ...  0.175624 -0.416271
# ABCG1     0.294469 -0.111470  0.070997 -0.014775  ...  0.069693  0.103841
#
# Name          ZW10    ZWILCH     ZWINT      ZXDC    ZYG11B       ZYX  \
# Name
# A1BG     -0.510477 -0.226919 -0.172136 -0.006482  0.441006  0.745865
# A2M      -0.562730 -0.265319 -0.199298 -0.048078  0.459178  0.731971
# AAAS      0.197701  0.255990  0.258646 -0.041678 -0.018214 -0.184958
# AACS      0.543128  0.403787  0.349544  0.072832 -0.376044 -0.709686
# AADAC    -0.291992 -0.332699 -0.398210 -0.020396  0.310992  0.459371
# AADAT    -0.192751 -0.020571  0.020597 -0.106017  0.459392  0.292931
# AAED1    -0.347324 -0.133367  0.032661  0.064273  0.362319  0.594089
# AAGAB     0.411844  0.487383  0.374069 -0.007134 -0.274914 -0.444520
# AAMDC    -0.268642 -0.307102 -0.281609 -0.093754  0.319575  0.526470
# AAMP      0.174190  0.131638  0.150568  0.134406 -0.313643 -0.333449
# AAR2      0.361262  0.353352  0.239665  0.044439  0.086317 -0.151222
# AARS      0.538758  0.422919  0.357583  0.051891 -0.422936 -0.677433
# AARS2     0.342152  0.325376  0.352757 -0.072379  0.045295 -0.414018
# AARSD1    0.403150  0.420048  0.316690  0.038070 -0.289739 -0.451174
# AASDHPPT  0.486645  0.273150  0.221845 -0.014329 -0.135265 -0.454093
# AASS      0.035838  0.145791  0.127387  0.095169  0.040541  0.015994
# AATF      0.531267  0.484528  0.464175  0.039362 -0.304975 -0.675856
# AATK     -0.332937 -0.416184 -0.466845  0.070981  0.163516  0.462168
# ABAT     -0.000462 -0.136399 -0.088474 -0.067801  0.091294 -0.234320
# ABCA1    -0.000776  0.226446  0.226794  0.057188  0.272629  0.231352
# ABCA12   -0.292309 -0.185476 -0.249381  0.043710  0.365589  0.500094
# ABCA13   -0.134825 -0.243490 -0.217481 -0.061564  0.225590  0.367717
# ABCA2     0.054202  0.006034  0.144976  0.102970 -0.091180 -0.156727
# ABCA3    -0.474797 -0.370875 -0.369934  0.016064  0.425719  0.669847
# ABCA6    -0.540618 -0.314480 -0.243848  0.015432  0.446746  0.752342
# ABCA7     0.368507  0.145107  0.264590  0.234933 -0.139647 -0.308978
# ABCA8    -0.553315 -0.408682 -0.383742 -0.008956  0.519343  0.846049
# ABCB1    -0.406851 -0.267701 -0.154692  0.085864  0.262765  0.628875
# ABCB10   -0.010356  0.083921  0.124277 -0.180406  0.039867  0.069904
# ABCB5     0.135397  0.160516 -0.002183  0.165659  0.002443  0.022437
# ABCB6    -0.285817 -0.165636 -0.049247 -0.178065  0.232249  0.120994
# ABCB7     0.326475  0.383779  0.351239 -0.056092 -0.025698 -0.370572
# ABCB8     0.114386  0.038047  0.072591 -0.212511  0.084780 -0.070035
# ABCC1     0.119115  0.006936  0.130275 -0.121414 -0.011841 -0.145103
# ABCC10   -0.281192 -0.256624 -0.272511 -0.083711  0.296964  0.190384
# ABCC2    -0.204734  0.120600  0.111198 -0.034430  0.070236  0.221763
# ABCC3     0.158010 -0.124755  0.040373 -0.167279 -0.056387 -0.445808
# ABCC4    -0.211525 -0.270957 -0.235371 -0.082717  0.273494  0.037542
# ABCC4    -0.289775 -0.282181 -0.325821 -0.061362  0.331368  0.122542
# ABCC5     0.138417  0.222782  0.128317  0.243102  0.015026 -0.118683
# ABCC6    -0.237058 -0.450151 -0.233363 -0.177028  0.431063  0.315307
# ABCC8    -0.280245 -0.050684  0.060175 -0.002000  0.202910  0.405355
# ABCD1     0.227031  0.179477  0.214859 -0.067740 -0.027691 -0.194398
# ABCD3     0.261880 -0.072370  0.012037 -0.144388 -0.017436 -0.274223
# ABCD4     0.080078 -0.106607  0.005893 -0.165776  0.020323 -0.056329
# ABCE1     0.552983  0.541987  0.442036  0.125690 -0.450226 -0.633258
# ABCF1     0.545229  0.429226  0.343771  0.137182 -0.396575 -0.649659
# ABCF2     0.540515  0.489343  0.374027  0.087386 -0.445475 -0.595930
# ABCF3     0.438688  0.374391  0.313069  0.186409 -0.397023 -0.509635
# ABCG1    -0.012229 -0.166920 -0.121912  0.178374 -0.006753  0.144392
#
# Name         ZZEF1      ZZZ3
# Name
# A1BG      0.627249  0.490107
# A2M       0.636374  0.475882
# AAAS     -0.142103  0.112737
# AACS     -0.428686 -0.268527
# AADAC     0.463094  0.240429
# AADAT     0.148797  0.149670
# AAED1     0.536203  0.451305
# AAGAB    -0.309802 -0.233174
# AAMDC     0.272022  0.246148
# AAMP     -0.264928 -0.199508
# AAR2     -0.053882 -0.025659
# AARS     -0.530762 -0.345310
# AARS2    -0.400730 -0.000199
# AARSD1   -0.422110 -0.134986
# AASDHPPT -0.374767 -0.200505
# AASS      0.270972  0.202281
# AATF     -0.587069 -0.238341
# AATK      0.319841  0.367574
# ABAT     -0.188192 -0.139008
# ABCA1     0.373997  0.160294
# ABCA12    0.397311  0.397801
# ABCA13    0.163266  0.217687
# ABCA2    -0.137719 -0.032890
# ABCA3     0.695251  0.366047
# ABCA6     0.654492  0.442591
# ABCA7    -0.284404 -0.145957
# ABCA8     0.687683  0.444491
# ABCB1     0.460923  0.392135
# ABCB10    0.177191 -0.133693
# ABCB5     0.133470  0.069428
# ABCB6     0.020622  0.186230
# ABCB7    -0.191762 -0.196084
# ABCB8     0.037036 -0.204881
# ABCC1    -0.016406 -0.117312
# ABCC10    0.090049  0.194554
# ABCC2     0.239723  0.143184
# ABCC3    -0.489236 -0.191040
# ABCC4     0.125034  0.120305
# ABCC4     0.278537  0.265938
# ABCC5     0.023843 -0.108772
# ABCC6     0.244008  0.280412
# ABCC8     0.362475  0.323364
# ABCD1    -0.068339 -0.189141
# ABCD3    -0.121289 -0.160915
# ABCD4    -0.206127  0.003158
# ABCE1    -0.468284 -0.312901
# ABCF1    -0.542803 -0.357218
# ABCF2    -0.516345 -0.280987
# ABCF3    -0.360764 -0.218046
# ABCG1     0.351033 -0.125561
#
# [50 rows x 10699 columns]

# %% [markdown]
# ###Note for Practice Problems
#
# Computing a correlation in a dataframe with df.corr() is rather quick. Doing the same with scipy.stats.pearsonr() would be a lot slower because it is calculating the correlation coefficient along with the p-value - and calculating the p-value is slow if you're doing it a million times in our large df.
#
# For efficiency in this homework, we have decided to use <-0.3 and >0.3 as the critical value for a 'significant' correlation. It's a reasonable assumption based on our experience with this dataset. But we note that it is not a strictly 'statistical' cutoff. Also in this homework, a strong correlation is <-0.6 and >0.6. In the real world, calculating and using the p-value would be necessary. Here we're just trying to save ~30-60 minutes of CPU thrashing.

# %% [markdown]
# ##PRACTICE PROBLEMS
# 1. For MSH2 in the LUAD correlation data, which protein has the highest correlation coefficient?

# %%
###       Question 1         ###
#  For MSH2 in the LUAD correlation data, which protein has the highest correlation coefficient?
#  You should derive your answer with coding, not any shortcuts.

###      Your code here      ###
max = -1
index = 0
MSH2 = lu_correlation['MSH2']
for i in range(len(MSH2)):
  if MSH2[i] > max and MSH2[i] != 1:
    max = MSH2[i]
    index = i
answer_1 = MSH2.index[index]
print(answer_1)
# Out:
# MSH6

# %%
###  Question 1: Submitting the answer   ###
# To submit, your code above should have created a variable 'answer_1'.
result = hw.submit(question = 1, answer = answer_1)
print(result)
# Out:
# True

# %%
### Question 1: Getting help ###
hints = hw.getHint(question=1)
print(hints)
# Out:
# Question 1 hints:
# *Proteins can have a very high negative or positive correlation.
# *Do not include MSH2's self correlation.
# *Only return the protein name.

# %% [markdown]
# 2. How many proteins have a positive correlation with TP53 in all of the following tumor types: LUAD, LSCC, HNSCC?

# %%
ls_clin_prot = ls.join_metadata_to_omics(metadata_df_name='clinical',
  omics_df_name='proteomics',
  metadata_cols = ["Sample_Tumor_Normal"])
lscc_no_id = ut.reduce_multiindex(df=ls_clin_prot, levels_to_drop="Database_ID")

hn_clin_prot = hn.join_metadata_to_omics(metadata_df_name='clinical',
  omics_df_name='proteomics',
  metadata_cols = ["Sample_Tumor_Normal"])
hnscc_no_id = ut.reduce_multiindex(df=hn_clin_prot)#, levels_to_drop="Database_ID")

ls_proteomics = ls.get_proteomics()
ls_prot_no_id = ut.reduce_multiindex(df=ls_proteomics, levels_to_drop="Database_ID")
ls_correlation = ls_prot_no_id.corr(method='pearson')

hn_proteomics = hn.get_proteomics()
hn_prot_no_id = ut.reduce_multiindex(df=hn_proteomics)#, levels_to_drop="Database_ID")
hn_correlation = hn_prot_no_id.corr(method='pearson')
# Out:
# cptac warning: proteomics data was not found for the following samples, so proteomics data columns were filled with NaN for these samples: C3L-00503, C3L-00503.N, C3L-02624, C3L-02624.N, C3N-00309, C3N-00839, C3N-01018, C3N-01018.N, C3N-02300.N, Samples-altered, Samples-amp, Samples-del (/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py, line 3)
# cptac warning: Due to dropping the specified levels, dataframe now has 858 duplicated column headers. (/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py, line 4)
# cptac warning: proteomics data was not found for the following samples, so proteomics data columns were filled with NaN for these samples: C3L-00977.N, C3L-04025.N, C3L-04791.N, C3N-00300, C3N-01643, C3N-01948.N, C3N-02333.N, C3N-02727.N, C3N-02925.N, C3N-03226.N, C3N-03487.N, C3N-03889.N, C3N-04152.N, C3N-04611.N (/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py, line 8)
# cptac warning: Due to dropping the specified levels, dataframe now has 858 duplicated column headers. (/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py, line 12)

# %%
###       Question 2         ###
#  How many proteins have a positive correlation with TP53 in all of the following tumor types: LUAD, LSCC, HNSCC?
#  Your answer should be in the format "cancer_# of proteins".
#  Each cancer should be in alphabetical order and separated by a comma and a space.
#  e.g. HNSCC_4209, LSCC_2384,...
#  You should derive your answer with coding, not any shortcuts.

###      Your code here      ###
import numpy as np

def correlated(x):
  if x == 1.0:
    return False
  elif x > 0:
    return True
  else:
    return False

lu_TP53 = lu_correlation['TP53']
ls_TP53 = ls_correlation['TP53']
hn_TP53 = hn_correlation['TP53']
answer = []
answer.append('LUAD' + '_' + str(np.count_nonzero(lu_TP53.apply(correlated))))
answer.append('LSCC' + '_' + str(np.count_nonzero(ls_TP53.apply(correlated))))
answer.append('HNSCC' + '_' + str(np.count_nonzero(hn_TP53.apply(correlated))))
answer.sort()
answer_2 = ''
for cancer in answer:
  answer_2 = answer_2 + cancer + ', '
answer_2 = answer_2[:-2]
print(answer_2)
# Out:
# HNSCC_5755, LSCC_5536, LUAD_4832

# %%
###  Question 2: Submitting the answer   ###
# To submit, your code above should have created a variable 'answer_2'.


result = hw.submit(question = 2, answer = answer_2)
print(result)
# Out:
# True

# %%
### Question 2: Getting help ###
hints = hw.getHint(question=2)
print(hints)
# Out:
# Question 2 hints:
# *Make a function to go through each cancer and get the TP53 correlation coefficients.
# *Try using an apply function to count how many correlation coefficients are > 0.
# *DO NOT count the self correlation value of 1.0.
# *Make sure your answer is in alphabetical order and formatted like the example given.
# *Make sure you spell out each cancer the same way they are written in the question.

# %% [markdown]
# # Part 3. Correlation Networks

# %% [markdown]
# There is a great visual map called a correlation or [co-expression network](https://en.wikipedia.org/wiki/Gene_co-expression_network), where we can see the similarity of protein abundance based on their correlation coefficients. If we made one with our complete correlation network, it would use so much RAM that it would crash our colab; It would look something like this.

# %% [markdown]
# ![Screen Shot 2021-04-08 at 12.31.42 PM.png](data:image/png;base64,...)

# %% [markdown]
# This is called a hairball and it is not good. We can't learn anything from this network! It would be much better to look at a few genes and their interactions. Let's look at our ribosomal proteins, RPS13 and RPS11, since we know they are highly correlated.

# %%
#Get the correlation between RPS13 and RPS11.
rps_interactions = lu_correlation[['RPS13', 'RPS11']]
rps_interactions.columns.name = 'gene1'
rps_interactions.index.name = 'gene2'
rps_links = rps_interactions.stack().reset_index()
rps_links.columns = ['gene1', 'gene2', 'value']

print(rps_links)
# Out:
#        gene1  gene2     value
# 0       A1BG  RPS13 -0.448673
# 1       A1BG  RPS11 -0.527492
# 2        A2M  RPS13 -0.513449
# 3        A2M  RPS11 -0.545298
# 4       AAAS  RPS13  0.135141
# ...      ...    ...       ...
# 21393    ZYX  RPS11 -0.505758
# 21394  ZZEF1  RPS13 -0.421838
# 21395  ZZEF1  RPS11 -0.407370
# 21396   ZZZ3  RPS13 -0.198129
# 21397   ZZZ3  RPS11 -0.207120
#
# [21398 rows x 3 columns]

# %%
import networkx as nx
#Keep only correlation over a threshold and remove self correlation (cor(A,A)=1).
rps_links_filtered=rps_links.loc[(rps_links['value'] > 0.6) & (rps_links['gene1'] != rps_links['gene2'])]

#Build your graph.
rps_G=nx.from_pandas_edgelist(rps_links_filtered, 'gene1', 'gene2')

#Plot the network.
nx.draw(rps_G, with_labels=True, node_color='orange', node_size=1000, edge_color='black', linewidths=1, font_size=10)

# %% [markdown]
# In the middle of this image is a tightly clustered group of proteins from the ribosome. You can spot them by their names 'RPL#' and 'RPS#', including RPS11 and RPS13. This bunch is highly connected with each other. At the edge of the image you also see a cresent moon shaped group of proteins that are only connected to RPS11, and not the rest of the network. This points to a distinct function of RPS11.
#
# Let's look at PTEN and CDC27 to see the type of correlation network they have.

# %%
#Make a correlation network with PTEN and CDC27.
###   Your code here  ###
pten_cdc_interactions = lu_correlation[['PTEN', 'CDC27']]
pten_cdc_interactions.columns.name = 'gene1'
pten_cdc_interactions.index.name = 'gene2'
pten_cdc_links = pten_cdc_interactions.stack().reset_index()
pten_cdc_links.columns = ['gene1', 'gene2', 'value']
pten_cdc_links_filtered=pten_cdc_links.loc[(pten_cdc_links['value'] > 0.6) & (pten_cdc_links['gene1'] != pten_cdc_links['gene2'])]

#Build your graph.
pten_cdc_G=nx.from_pandas_edgelist(pten_cdc_links_filtered, 'gene1', 'gene2')

#Plot the network.
nx.draw(pten_cdc_G, with_labels=True, node_color='orange', node_size=1000, edge_color='black', linewidths=1, font_size=10)

# %% [markdown]
# So, different.\
# PTEN and CDC27 are each isolated on their own small network. Their correlation coefficient was negative, so it was unlikely that they had a lot in common.

# %% [markdown]
# ## PRACTICE PROBLEMS
#
# 3. In the breast cancer cohort, how many proteins have a significant positive correlation with ERBB2 in stage III?

# %%
cptac.download('brca')
br = cptac.Brca()
br_proteomics = br.get_proteomics()
br_prot_no_id = ut.reduce_multiindex(df=br_proteomics, levels_to_drop="Database_ID")
br_correlation = br_prot_no_id.corr(method='pearson')
# Out:
# cptac warning: Due to dropping the specified levels, dataframe now has 655 duplicated column headers. (/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py, line 4)

# %%
list(set(br_clin_prot['Stage']))
# Out:
# [nan,
#  'Stage IIIB',
#  'Stage IIB',
#  'Stage IIA',
#  'Stage III',
#  'Stage IIIC',
#  'Stage IIIA',
#  'Stage IA']

# %%
###       Question 3         ###
#  In the breast cancer cohort, how many proteins have a significant positive correlation with ERBB2 in stage III?
#  You should derive your answer with coding, not any shortcuts.

###      Your code here      ###
# HINT. to access breast cancer data, use -

def stage3(x):
  x = str(x)
  if x == float('nan'):
    return False
  elif 'III' in x:
    return True
  else:
    return False
br_clin_prot = br.join_metadata_to_omics(metadata_df_name='clinical',
  omics_df_name='proteomics',
  metadata_cols = ["Stage"])
#Some functions require that we drop the Database_ID column.
brca_no_id = ut.reduce_multiindex(df=br_clin_prot, levels_to_drop="Database_ID")
brca_stage3 = brca_no_id.loc[brca_no_id['Stage'].apply(stage3)]
brca_stage3_correlation = brca_stage3.corr(method='pearson')
brca_stage3_correlation

def sigCorrelated(x):
  if x == 1:
    return False
  elif x > .3:
    return True
  else:
    return False

brca_ERBB2_3 = brca_stage3_correlation['ERBB2_proteomics']

answer_3 = np.count_nonzero(brca_ERBB2_3.apply(sigCorrelated))
print(answer_3)
# Out:
# cptac warning: Due to dropping the specified levels, dataframe now has 655 duplicated column headers. (/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py, line 20)
# 692

# %%
###  Question 3: Submitting the answer   ###
# To submit, your code above should have created a variable 'answer_3'.
result = hw.submit(question = 3, answer = answer_3)
print(result)
# Out:
# True

# %%
### Question 3: Getting help ###
hints = hw.getHint(question=3)
print(hints)
# Out:
# Question 3 hints:
# *Make sure you look through every version of stage III.
# *Don't count the ERBB2 self correlation.
# *You might need to include the database ID to select ERBB2 from the correlation df.

# %% [markdown]
# 4. In the breast cancer cohort, how many proteins have a significant positive correlation with ERBB2 in stage II?

# %%
###       Question 4         ###
#  In the breast cancer cohort, how many proteins have a significant positive correlation with ERBB2 in stage II?
#  You should derive your answer with coding, not any shortcuts.

###      Your code here      ###
def stage2(x):
  if x == float('nan'):
    return False
  elif x == 'Stage IIA' or x == 'Stage IIB':
    return True
  else:
    return False


brca_stage2 = brca_no_id.loc[brca_no_id['Stage'].apply(stage2)]
brca_stage2_correlation = brca_stage2.corr(method='pearson')
brca_stage2_correlation
brca_ERBB2_2 = brca_stage2_correlation['ERBB2_proteomics']

answer_4 = np.count_nonzero(brca_ERBB2_2.apply(sigCorrelated))
print(answer_4)
# Out:
# 496

# %%
###  Question 4: Submitting the answer   ###
# To submit, your code above should have created a variable 'answer_4'.
result = hw.submit(question = 4, answer = answer_4)
print(result)
# Out:
# True

# %%
### Question 4: Getting help ###
hints = hw.getHint(question=4)
print(hints)
# Out:
# Question 4 hints:
# *Make sure you look through every version of stage II.
# *Don't count the ERBB2 self correlation.
# *You might need to include the database ID to select ERBB2 from the correlation df.

# %% [markdown]
# 5. In the LUAD cohort, we previously made an interaction network with RPS11 that included the ribosome and associated translational machinery. Which proteins have a highly negative interaction with RPS11?

# %%
RPS11 = lu_correlation['RPS11']
RPS11 < -.5
# Out:
# gene2
# A1BG       True
# A2M        True
# AAAS      False
# AACS      False
# AADAC     False
#           ...
# ZXDC      False
# ZYG11B    False
# ZYX        True
# ZZEF1     False
# ZZZ3      False
# Name: RPS11, Length: 10699, dtype: bool

# %%
###       Question 5         ###
#  In the LUAD cohort, we previously made an interaction network with RPS11 that included the ribosome and associated translational machinery.
#  Which proteins have a highly negative interaction with RPS11?
#  Your answer should be a string with each protein separated by a comma and a space in alphabetical order.
#  You should derive your answer with coding, not any shortcuts.

###      Your code here      ###
RPS11 = lu_correlation['RPS11']
#RPS11 = RPS11.loc[RPS11.index != 'RPS11']
RPS11 = RPS11.loc[RPS11 < -.6]
neg_genes = list(RPS11.index)
#list(set(RPS11.index)) using a set to check for uniques gives 101 rather than 104 genes
#because some genes, such as DMTN, appear multiple times
neg_genes.sort()
answer_5 = ''
for gene in neg_genes:
  answer_5 = answer_5 + gene + ', '
answer_5 = answer_5[:-2]
print(len(neg_genes))
print(answer_5)
# Out:
# 104
# ACP5, ACVRL1, AGER, AKAP2, ALAD, ALDH1A1, ALOX5, ANK1, ARHGAP31, ARHGAP6, ARL8B, ARRB1, BLVRB, BPGM, CA1, CA4, CALCRL, CALM3, CASKIN2, CAT, CAVIN2, CCDC22, CES1, CES1, CLIC2, CYP27A1, DDI2, DMTN, DMTN, DMXL1, DOCK9, EHD2, EPB41, EPB42, ESAM, FBP1, FBXO7, GCHFR, GFOD1, GMPR, GNB2, GNG11, GPD1, GRASP, GYPA, GYPC, HAGH, HBA2, HBB, HBD, HBZ, HPCAL1, HSPA12B, HYI, IDS, JMJD7, KEL, LAMTOR3, MPP1, MRAS, MVB12B, NEBL, NEBL, NIPSNAP3A, OSBPL1A, PCMT1, PITHD1, PKLR, PLLP, PRAMEF12, PRDX2, PRX, QKI, RAD23A, RASSF8, RILP, RNF123, RNF13, ROGDI, RPIA, RSU1, SHANK3, SLC39A10, SLC4A1, SNCA, SPG11, SPTA1, STARD13, STX11, STXBP6, SULT1A1, SULT1A2, TANGO2, TAS1R3, TBCEL, THBD, TNNC1, TRPV2, TTLL4, UBAC1, VAT1, VIPR1, VPS26C, ZBTB39

# %%
###  Question 5: Submitting the answer   ###
# To submit, your code above should have created a variable 'answer_5'.
result = hw.submit(question = 5, answer = answer_5)
print(result)
# Out:
# True

# %%
### Question 5: Getting help ###
hints = hw.getHint(question=5)
print(hints)
# Out:
# Question 5 hints:
# *Make sure you understand what a highly negative correlation is.
# *Try using a complex selection with the right conditions.
# *Make sure your answer is formated correctly.

# %% [markdown]
# # Part 4. Interactions

# %% [markdown]
# It is now important to compare the results we have found to the known interactions in UniProt.

# %%
import requests

url = 'https://rest.uniprot.org/uniprotkb/search'

params = {
    'format': 'list',
    'query': 'gene_exact:pten AND organism_id:9606 AND reviewed:true'
}

response = requests.get(url, params=params)
pten_accession = response.text.rstrip()
print(pten_accession)
# Out:
# P60484

# %%
interactions_response = requests.get('https://www.ebi.ac.uk/proteins/api/proteins/interaction/' + pten_accession)
print(type(interactions_response))
print(interactions_response.text)
# Out:
# <class 'requests.models.Response'>
# [{"accession":"P60484","name":"PTEN_HUMAN","proteinExistence":"Evidence at protein level","taxonomy":9606,"interactions":[{"accession1":"P60484","accession2":"P35226","gene":"BMI1","interactor1":"EBI-696162","interactor2":"EBI-2341576","organismDiffer":false,"experiments":7},{"accession1":"P60484","accession2":"P30260","gene":"CDC27","interactor1":"EBI-696162","interactor2":"EBI-994813","organismDiffer":false,"experiments":7},{"accession1":"P60484","accession2":"Q9P0U4","gene":"CXXC1","interactor1":"EBI-696162","interactor2":"EBI-949911","organismDiffer":false,"experiments":2},{"accession1":"P60484","accession2":"Q16643","gene":"DBN1","interactor1":"EBI-696162","interactor2":"EBI-351394","organismDiffer":false,"experiments":5},{"accession1":"P60484","accession2":"P42685","gene":"FRK","interactor1":"EBI-696162","interactor2":"EBI-1383583","organismDiffer":false,"experiments":7},{"accession1":"P60484","accession2":"O60307","gene":"MAST3","interactor1":"EBI-696162","interactor2":"EBI-311420","organismDiffer":false,"experiments":3},{"accession1":"P60484","accession2":"Q9Y6Q9","gene":"NCOA3","interactor1":"EBI-696162","interactor2":"EBI-81196","organismDiffer":false,"experiments":2},{"accession1":"P60484","accession2":"P46934","gene":"NEDD4","interactor1":"EBI-696162","interactor2":"EBI-726944","organismDiffer":false,"experiments":4},{"accession1":"P60484","accession2":"P09619","gene":"PDGFRB","interactor1":"EBI-696162","interactor2":"EBI-641237","organismDiffer":false,"experiments":3},{"accession1":"P60484","accession2":"Q9NRD5","gene":"PICK1","interactor1":"EBI-696162","interactor2":"EBI-79165","organismDiffer":false,"experiments":2},{"accession1":"P60484","accession2":"P62136","gene":"PPP1CA","interactor1":"EBI-696162","interactor2":"EBI-357253","organismDiffer":false,"experiments":2},{"accession1":"P60484","accession2":"Q06830","gene":"PRDX1","interactor1":"EBI-696162","interactor2":"EBI-353193","organismDiffer":false,"experiments":7},{"accession1":"P60484","accession2":"P60484","gene":"PTEN","interactor1":"EBI-696162","interactor2":"EBI-696162","organismDiffer":false,"experiments":9},{"accession1":"P60484","accession2":"O14745","gene":"SLC9A3R1","interactor1":"EBI-696162","interactor2":"EBI-349787","organismDiffer":false,"experiments":7},{"accession1":"P60484","accession2":"Q15599","gene":"SLC9A3R2","interactor1":"EBI-696162","interactor2":"EBI-1149760","organismDiffer":false,"experiments":5},{"accession1":"P60484","accession2":"O43791","gene":"SPOP","interactor1":"EBI-696162","interactor2":"EBI-743549","organismDiffer":false,"experiments":4},{"accession1":"P60484","accession2":"Q62696","gene":"Dlg1","interactor1":"EBI-696162","interactor2":"EBI-389325","organismDiffer":true,"experiments":2},{"accession1":"P60484","accession2":"O88382","gene":"Magi2","interactor1":"EBI-696162","interactor2":"EBI-696179","organismDiffer":true,"experiments":3},{"accession1":"P60484","accession2":"Q9JK71","gene":"Magi3","interactor1":"EBI-696162","interactor2":"EBI-696226","organismDiffer":true,"experiments":3},{"accession1":"P60484","accession2":"Q9R1L5","gene":"Mast1","interactor1":"EBI-696162","interactor2":"EBI-491771","organismDiffer":true,"experiments":3},{"accession1":"P60484","accession2":"Q60592","gene":"Mast2","interactor1":"EBI-696162","interactor2":"EBI-493888","organismDiffer":true,"experiments":4},{"accession1":"P60484","accession2":"Q9JHL1","gene":"Slc9a3r2","interactor1":"EBI-696162","interactor2":"EBI-538451","organismDiffer":true,"experiments":2},{"accession1":"P60484-1","accession2":"Q19T08","gene":"ECSCR","interactor1":"EBI-15722967","interactor2":"EBI-15778214","organismDiffer":false,"experiments":4},{"accession1":"P60484-1","accession2":"Q5T2D3","gene":"OTUD3","interactor1":"EBI-15722967","interactor2":"EBI-16170539","organismDiffer":false,"experiments":9},{"accession1":"P60484-1","accession2":"P60484-1","gene":"PTEN","interactor1":"EBI-15722967","interactor2":"EBI-15722967","organismDiffer":false,"experiments":3},{"accessio ...

# %%
#the python library to help with JSON objects
import json
json_var_dictionary = json.loads(interactions_response.text)
json_var_dictionary #look at the information provided in this dictionary and try to understand the output
# Out:
# [{'accession': 'P60484',
#   'name': 'PTEN_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
#   'interactions': [{'accession1': 'P60484',
#     'accession2': 'P35226',
#     'gene': 'BMI1',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-2341576',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'P60484',
#     'accession2': 'P30260',
#     'gene': 'CDC27',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-994813',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'P60484',
#     'accession2': 'Q9P0U4',
#     'gene': 'CXXC1',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-949911',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P60484',
#     'accession2': 'Q16643',
#     'gene': 'DBN1',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-351394',
#     'organismDiffer': False,
#     'experiments': 5},
#    {'accession1': 'P60484',
#     'accession2': 'P42685',
#     'gene': 'FRK',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-1383583',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'P60484',
#     'accession2': 'O60307',
#     'gene': 'MAST3',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-311420',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P60484',
#     'accession2': 'Q9Y6Q9',
#     'gene': 'NCOA3',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-81196',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P60484',
#     'accession2': 'P46934',
#     'gene': 'NEDD4',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-726944',
#     'organismDiffer': False,
#     'experiments': 4},
#    {'accession1': 'P60484',
#     'accession2': 'P09619',
#     'gene': 'PDGFRB',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-641237',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P60484',
#     'accession2': 'Q9NRD5',
#     'gene': 'PICK1',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-79165',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P60484',
#     'accession2': 'P62136',
#     'gene': 'PPP1CA',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-357253',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P60484',
#     'accession2': 'Q06830',
#     'gene': 'PRDX1',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-353193',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'P60484',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': False,
#     'experiments': 9},
#    {'accession1': 'P60484',
#     'accession2': 'O14745',
#     'gene': 'SLC9A3R1',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-349787',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'P60484',
#     'accession2': 'Q15599',
#     'gene': 'SLC9A3R2',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-1149760',
#     'organismDiffer': False,
#     'experiments': 5},
#    {'accession1': 'P60484',
#     'accession2': 'O43791',
#     'gene': 'SPOP',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-743549',
#     'organismDiffer': False,
#     'experiments': 4},
#    {'accession1': 'P60484',
#     'accession2': 'Q62696',
#     'gene': 'Dlg1',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-389325',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'P60484',
#     'accession2': 'O88382',
#     'gene': 'Magi2',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-696179',
#     'organismDiffer': True,
#     'experiments': 3},
#    {'accession1': 'P60484',
#     'accession2': 'Q9JK71',
#     'gene': 'Magi3',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-696226',
#     'organismDiffer': True,
#     'experiments': 3},
#    {'accession1': 'P60484',
#     'accession2': 'Q9R1L5',
#     'gene': 'Mast1',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-491771',
#     'organismDiffer': True,
#     'experiments': 3},
#    {'accession1': 'P60484',
#     'accession2': 'Q60592',
#     'gene': 'Mast2',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-493888',
#     'organismDiffer': True,
#     'experiments': 4},
#    {'accession1': 'P60484',
#     'accession2': 'Q9JHL1',
#     'gene': 'Slc9a3r2',
#     'interactor1': 'EBI-696162',
#     'interactor2': 'EBI-538451',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'P60484-1',
#     'accession2': 'Q19T08',
#     'gene': 'ECSCR',
#     'interactor1': 'EBI-15722967',
#     'interactor2': 'EBI-15778214',
#     'organismDiffer': False,
#     'experiments': 4},
#    {'accession1': 'P60484-1',
#     'accession2': 'Q5T2D3',
#     'gene': 'OTUD3',
#     'interactor1': 'EBI-15722967',
#     'interactor2': 'EBI-16170539',
#     'organismDiffer': False,
#     'experiments': 9},
#    {'accession1': 'P60484-1',
#     'accession2': 'P60484-1',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-15722967',
#     'interactor2': 'EBI-15722967',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P60484-1',
#     'accession2': 'Q93009',
#     'gene': 'USP7',
#     'interactor1': 'EBI-15722967',
#     'interactor2': 'EBI-302474',
#     'organismDiffer': False,
#     'experiments': 5}],
#   'diseases': [{'type': 'DISEASE',
#     'diseaseId': 'Cowden syndrome 1',
#     'acronym': 'CWS1',
#     'dbReference': {'type': 'MIM', 'id': '158350'},
#     'description': {'value': 'An autosomal dominant hamartomatous polyposis syndrome with age-related penetrance. Cowden syndrome is characterized by hamartomatous lesions affecting derivatives of ectodermal, mesodermal and endodermal layers, macrocephaly, facial trichilemmomas (benign tumors of the hair follicle infundibulum), acral keratoses, papillomatous papules, and elevated risk for development of several types of malignancy, particularly breast carcinoma in women and thyroid carcinoma in both men and women. Colon cancer and renal cell carcinoma have also been reported. Hamartomas can be found in virtually every organ, but most commonly in the skin, gastrointestinal tract, breast and thyroid.',
#      'evidences': [{'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '10051160',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/10051160',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/10051160'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '10234502',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/10234502',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/10234502'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '10400993',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/10400993',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/10400993'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '10866302',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/10866302',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/10866302'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '11230179',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11230179',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/11230179'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '11494117',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11494117',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/11494117'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '15355975',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15355975',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/15355975'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '18716620',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18716620',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/18716620'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9140396',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9140396',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9140396'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9241266',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9241266',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9241266'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9259288',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9259288',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9259288'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9345101',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9345101',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9345101'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9399897',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9399897',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9399897'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9425889',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9425889',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9425889'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9467011',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9467011',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9467011'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9600246',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9600246',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9600246'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9735393',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9735393',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9735393'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9797362',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9797362',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9797362'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9811831',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9811831',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9811831'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9832031',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9832031',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9832031'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9915974',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9915974',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9915974'}}]},
#     'text': [{'value': 'The disease is caused by variants affecting the gene represented in this entry'}]},
#    {'type': 'DISEASE',
#     'diseaseId': 'Lhermitte-Duclos disease',
#     'acronym': 'LDD',
#     'dbReference': {'type': 'MIM', 'id': '158350'},
#     'description': {'value': 'A rare disease characterized by the occurrence of a slowly enlarging mass within the cerebellar cortex corresponding histologically to a cerebellar hamartoma. It manifests, most commonly in the third and fourth decades of life, with increased intracranial pressure, headache, nausea, cerebellar dysfunction, occlusive hydrocephalus, ataxia, visual disturbances and other cranial nerve palsies. Various associated abnormalities may be present such as megalencephaly, microgyria, hydromyelia, polydactyly, partial gigantism, macroglossia. LDD is part of the PTEN hamartoma tumor syndromes spectrum that also includes Cowden syndrome.'},
#     'text': [{'value': 'The disease is caused by variants affecting the gene represented in this entry'}]},
#    {'type': 'DISEASE',
#     'diseaseId': 'Squamous cell carcinoma of the head and neck',
#     'acronym': 'HNSCC',
#     'dbReference': {'type': 'MIM', 'id': '275355'},
#     'description': {'value': 'A non-melanoma skin cancer affecting the head and neck. The hallmark of cutaneous SCC is malignant transformation of normal epidermal keratinocytes.',
#      'evidences': [{'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '11801303',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11801303',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/11801303'}}]},
#     'text': [{'value': 'The disease is caused by variants affecting the gene represented in this entry'}]},
#    {'type': 'DISEASE',
#     'diseaseId': 'Endometrial cancer',
#     'acronym': 'ENDMC',
#     'dbReference': {'type': 'MIM', 'id': '608089'},
#     'description': {'value': 'A malignancy of endometrium, the mucous lining of the uterus. Most endometrial cancers are adenocarcinomas, cancers that begin in cells that make and release mucus and other fluids.'},
#     'text': [{'value': 'Disease susceptibility is associated with variants affecting the gene represented in this entry'}]},
#    {'type': 'DISEASE',
#     'text': [{'value': 'PTEN mutations are found in a subset of patients with Proteus syndrome, a genetically heterogeneous condition. The molecular diagnosis of PTEN mutation positive cases classifies Proteus syndrome patients as part of the PTEN hamartoma syndrome spectrum. As such, patients surviving the early years of Proteus syndrome are likely at a greater risk of developing malignancies'}]},
#    {'type': 'DISEASE',
#     'diseaseId': 'Glioma 2',
#     'acronym': 'GLM2',
#     'dbReference': {'type': 'MIM', 'id': '613028'},
#     'description': {'value': 'Gliomas are benign or malignant central nervous system neoplasms derived from glial cells. They comprise astrocytomas and glioblastoma multiforme that are derived from astrocytes, oligodendrogliomas derived from oligodendrocytes and ependymomas derived from ependymocytes.',
#      'evidences': [{'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '12085208',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/12085208',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/12085208'}}]},
#     'text': [{'value': 'Disease susceptibility is associated with variants affecting the gene represented in this entry'}]},
#    {'type': 'DISEASE',
#     'diseaseId': 'Prostate cancer',
#     'acronym': 'PC',
#     'dbReference': {'type': 'MIM', 'id': '176807'},
#     'description': {'value': 'A malignancy originating in tissues of the prostate. Most prostate cancers are adenocarcinomas that develop in the acini of the prostatic ducts. Other rare histopathologic types of prostate cancer that occur in approximately 5% of patients include small cell carcinoma, mucinous carcinoma, prostatic ductal carcinoma, transitional cell carcinoma, squamous cell carcinoma, basal cell carcinoma, adenoid cystic carcinoma (basaloid), signet-ring cell carcinoma and neuroendocrine carcinoma.',
#      'evidences': [{'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '26504226',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/26504226',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/26504226'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '9072974',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9072974',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/9072974'}}]},
#     'text': [{'value': 'Disease susceptibility is associated with variants affecting the gene represented in this entry'}]},
#    {'type': 'DISEASE',
#     'diseaseId': 'Macrocephaly/autism syndrome',
#     'acronym': 'MCEPHAS',
#     'dbReference': {'type': 'MIM', 'id': '605309'},
#     'description': {'value': 'Patients have autism spectrum disorders and macrocephaly, with head circumferences ranging from +2.5 to +8 SD for age and sex (average head circumference +4.0 SD).',
#      'evidences': [{'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '15805158',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15805158',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/15805158'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '23160955',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23160955',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/23160955'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '26637798',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/26637798',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/26637798'}}]},
#     'text': [{'value': 'The disease is caused by variants affecting the gene represented in this entry'}]},
#    {'type': 'DISEASE',
#     'text': [{'value': 'A microdeletion of chromosome 10q23 involving BMPR1A and PTEN is a cause of chromosome 10q23 deletion syndrome, which shows overlapping features of the following three disorders: Bannayan-Zonana syndrome, Cowden disease and juvenile polyposis syndrome'}]}],
#   'subcellularLocations': [{'type': 'SUBCELLULAR_LOCATION',
#     'locations': [{'location': {'value': 'Cytoplasm',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '15987703',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15987703',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/15987703'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '18716620',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18716620',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/18716620'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '19473982',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19473982',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/19473982'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '25801959',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25801959',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/25801959'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '9187108',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9187108',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/9187108'}}]}},
#      {'location': {'value': 'Nucleus',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '15987703',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15987703',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/15987703'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '18716620',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18716620',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/18716620'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '19473982',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19473982',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/19473982'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '25801959',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25801959',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/25801959'}}]}},
#      {'location': {'value': 'Nucleus, PML body',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '18716620',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18716620',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/18716620'}}]}},
#      {'location': {'value': 'Cell projection, dendritic spine',
#        'evidences': [{'code': 'ECO:0000250',
#          'source': {'name': 'UniProtKB',
#           'id': 'O54857',
#           'url': 'https://www.uniprot.org/uniprot/O54857'}}]}},
#      {'location': {'value': 'Postsynaptic density',
#        'evidences': [{'code': 'ECO:0000250',
#          'source': {'name': 'UniProtKB',
#           'id': 'O54857',
#           'url': 'https://www.uniprot.org/uniprot/O54857'}}]}}],
#     'text': [{'value': 'Monoubiquitinated form is nuclear. Nonubiquitinated form is cytoplasmic. Colocalized with PML and USP7 in PML nuclear bodies (PubMed:18716620). XIAP/BIRC4 promotes its nuclear localization (PubMed:19473982). Associares with the postsynaptic density in response to NMDAR activation (By similarity)',
#       'evidences': [{'code': 'ECO:0000250',
#         'source': {'name': 'UniProtKB',
#          'id': 'O54857',
#          'url': 'https://www.uniprot.org/uniprot/O54857'}},
#        {'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '18716620',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18716620',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/18716620'}},
#        {'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '19473982',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19473982',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/19473982'}}]}]},
#    {'type': 'SUBCELLULAR_LOCATION',
#     'molecule': 'Isoform alpha',
#     'locations': [{'location': {'value': 'Secreted',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '23744781',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23744781',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/23744781'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '24768297',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/24768297',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/24768297'}}]}}],
#     'text': [{'value': 'May be secreted via a classical signal peptide and reenter into cells with the help of a poly-Arg motif',
#       'evidences': [{'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '23744781',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/23744781',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/23744781'}},
#        {'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '24768297',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/24768297',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/24768297'}}]}]}]},
#  {'accession': 'O14745',
#   'name': 'NHRF1_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
#   'interactions': [{'accession1': 'O14745',
#     'accession2': 'Q9BYF1',
#     'gene': 'ACE2',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-7730807',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'O14745',
#     'accession2': 'P07550',
#     'gene': 'ADRB2',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-491169',
#     'organismDiffer': False,
#     'experiments': 6},
#    {'accession1': 'O14745',
#     'accession2': 'Q92624',
#     'gene': 'APPBP2',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-743771',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'O14745',
#     'accession2': 'P13569',
#     'gene': 'CFTR',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-349854',
#     'organismDiffer': False,
#     'experiments': 15},
#    {'accession1': 'O14745',
#     'accession2': 'P29762',
#     'gene': 'CRABP1',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-725950',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'O14745',
#     'accession2': 'Q9Y2H0-1',
#     'gene': 'DLGAP4',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-12000556',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'O14745',
#     'accession2': 'P15311',
#     'gene': 'EZR',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-1056902',
#     'organismDiffer': False,
#     'experiments': 6},
#    {'accession1': 'O14745',
#     'accession2': 'P26038',
#     'gene': 'MSN',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-528768',
#     'organismDiffer': False,
#     'experiments': 4},
#    {'accession1': 'O14745',
#     'accession2': 'P35240-1',
#     'gene': 'NF2',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-1014500',
#     'organismDiffer': False,
#     'experiments': 4},
#    {'accession1': 'O14745',
#     'accession2': 'P47900',
#     'gene': 'P2RY1',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-8677223',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'O14745',
#     'accession2': 'P09619',
#     'gene': 'PDGFRB',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-641237',
#     'organismDiffer': False,
#     'experiments': 5},
#    {'accession1': 'O14745',
#     'accession2': 'O60346',
#     'gene': 'PHLPP1',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-2511516',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'O14745',
#     'accession2': 'O60346-2',
#     'gene': 'PHLPP1',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-11165225',
#     'organismDiffer': False,
#     'experiments': 5},
#    {'accession1': 'O14745',
#     'accession2': 'Q6ZVD8',
#     'gene': 'PHLPP2',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-2511496',
#     'organismDiffer': False,
#     'experiments': 6},
#    {'accession1': 'O14745',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'O14745',
#     'accession2': 'O14745',
#     'gene': 'SLC9A3R1',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-349787',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'O14745',
#     'accession2': 'Q9R0W0',
#     'gene': 'mGluR1a',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-8505383',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'O14745',
#     'accession2': 'P26043',
#     'gene': 'Rdx',
#     'interactor1': 'EBI-349787',
#     'interactor2': 'EBI-647737',
#     'organismDiffer': True,
#     'experiments': 2}],
#   'diseases': [{'type': 'DISEASE',
#     'diseaseId': 'Nephrolithiasis/osteoporosis, hypophosphatemic, 2',
#     'acronym': 'NPHLOP2',
#     'dbReference': {'type': 'MIM', 'id': '612287'},
#     'description': {'value': 'A disease characterized by decreased renal phosphate absorption, renal phosphate wasting, hypophosphatemia, hyperphosphaturia, hypercalciuria, nephrolithiasis and osteoporosis.',
#      'evidences': [{'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '18784102',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18784102',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/18784102'}},
#       {'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '22506049',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/22506049',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/22506049'}}]},
#     'text': [{'value': 'The disease is caused by variants affecting the gene represented in this entry'}]}],
#   'subcellularLocations': [{'type': 'SUBCELLULAR_LOCATION',
#     'locations': [{'location': {'value': 'Cytoplasm',
#        'evidences': [{'code': 'ECO:0000250'}]}},
#      {'location': {'value': 'Apical cell membrane',
#        'evidences': [{'code': 'ECO:0000250'}]}},
#      {'location': {'value': 'Endomembrane system'},
#       'topology': {'value': 'Peripheral membrane protein'}},
#      {'location': {'value': 'Cell projection, filopodium'}},
#      {'location': {'value': 'Cell projection, ruffle'}},
#      {'location': {'value': 'Cell projection, microvillus'}}],
#     'text': [{'value': 'Translocates from the cytoplasm to the apical cell membrane in a PODXL-dependent manner. Colocalizes with CFTR at the midpiece of sperm tail (By similarity). Colocalizes with actin in microvilli-rich apical regions of the syncytiotrophoblast. Found in microvilli, ruffling membrane and filopodia of HeLa cells. Present in lipid rafts of T-cells',
#       'evidences': [{'code': 'ECO:0000250'}]}]}]},
#  {'accession': 'P46934',
#   'name': 'NEDD4_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
#   'interactions': [{'accession1': 'P46934',
#     'accession2': 'Q96B67',
#     'gene': 'ARRDC3',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-2875665',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934',
#     'accession2': 'P54259',
#     'gene': 'ATN1',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-945980',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'Q9H305',
#     'gene': 'CDIP1',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-2876678',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'P00533',
#     'gene': 'EGFR',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-297353',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934',
#     'accession2': 'P11362',
#     'gene': 'FGFR1',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-1028277',
#     'organismDiffer': False,
#     'experiments': 26},
#    {'accession1': 'P46934',
#     'accession2': 'O95166',
#     'gene': 'GABARAP',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-712001',
#     'organismDiffer': False,
#     'experiments': 6},
#    {'accession1': 'P46934',
#     'accession2': 'Q9H0R8',
#     'gene': 'GABARAPL1',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-746969',
#     'organismDiffer': False,
#     'experiments': 6},
#    {'accession1': 'P46934',
#     'accession2': 'P60520',
#     'gene': 'GABARAPL2',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-720116',
#     'organismDiffer': False,
#     'experiments': 6},
#    {'accession1': 'P46934',
#     'accession2': 'Q99732',
#     'gene': 'LITAF',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-725647',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'P46934',
#     'accession2': 'Q9GZQ8',
#     'gene': 'MAP1LC3B',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-373144',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934',
#     'accession2': 'Q14686',
#     'gene': 'NCOA6',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-78670',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'Q14934',
#     'gene': 'NFATC4',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-3905796',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'Q6GQQ9',
#     'gene': 'OTUD7B',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-527784',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'Q9UKN5',
#     'gene': 'PRDM4',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-2803427',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'Q9BZD6',
#     'gene': 'PRRG4',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-3918643',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': False,
#     'experiments': 4},
#    {'accession1': 'P46934',
#     'accession2': 'Q9Y3C5',
#     'gene': 'RNF11',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-396669',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934',
#     'accession2': 'P37088',
#     'gene': 'SCNN1A',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-7845444',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934',
#     'accession2': 'P51168',
#     'gene': 'SCNN1B',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-2547187',
#     'organismDiffer': False,
#     'experiments': 5},
#    {'accession1': 'P46934',
#     'accession2': 'Q8IV31',
#     'gene': 'TMEM139',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-7238458',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'Q8N4L1',
#     'gene': 'TMEM151A',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-25600031',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'O15417',
#     'gene': 'TNRC18',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-2824620',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'Q96PN7',
#     'gene': 'TRERF1',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-3505166',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934',
#     'accession2': 'P0CG47',
#     'gene': 'UBB',
#     'interactor1': 'EBI-726944',
#     'interactor2': 'EBI-413034',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934-3',
#     'accession2': 'Q9H0R8',
#     'gene': 'GABARAPL1',
#     'interactor1': 'EBI-11980721',
#     'interactor2': 'EBI-746969',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934-3',
#     'accession2': 'P60520',
#     'gene': 'GABARAPL2',
#     'interactor1': 'EBI-11980721',
#     'interactor2': 'EBI-720116',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934-3',
#     'accession2': 'A0A024R8L2',
#     'gene': 'hCG_1987119',
#     'interactor1': 'EBI-11980721',
#     'interactor2': 'EBI-14103818',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934-3',
#     'accession2': 'O15160',
#     'gene': 'POLR1C',
#     'interactor1': 'EBI-11980721',
#     'interactor2': 'EBI-1055079',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934-3',
#     'accession2': 'Q6ZSJ9',
#     'gene': 'SHISA6',
#     'interactor1': 'EBI-11980721',
#     'interactor2': 'EBI-12037847',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934-3',
#     'accession2': 'P84022',
#     'gene': 'SMAD3',
#     'interactor1': 'EBI-11980721',
#     'interactor2': 'EBI-347161',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934-3',
#     'accession2': 'Q05BL1',
#     'gene': 'TP53BP2',
#     'interactor1': 'EBI-11980721',
#     'interactor2': 'EBI-11952721',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P46934-3',
#     'accession2': 'P0DTC2',
#     'gene': 'S',
#     'interactor1': 'EBI-11980721',
#     'interactor2': 'EBI-25474821',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'P46934-4',
#     'accession2': 'Q9HAU4',
#     'gene': 'SMURF2',
#     'interactor1': 'EBI-16129814',
#     'interactor2': 'EBI-396727',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P46934-4',
#     'accession2': 'P62990',
#     'gene': 'UBC',
#     'interactor1': 'EBI-16129814',
#     'interactor2': 'EBI-413053',
#     'organismDiffer': True,
#     'experiments': 2}],
#   'subcellularLocations': [{'type': 'SUBCELLULAR_LOCATION',
#     'locations': [{'location': {'value': 'Cytoplasm',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '11342538',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11342538',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/11342538'}}]}},
#      {'location': {'value': 'Nucleus',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '11342538',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11342538',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/11342538'}}]}},
#      {'location': {'value': 'Cell membrane',
#        'evidences': [{'code': 'ECO:0000250',
#          'source': {'name': 'UniProtKB',
#           'id': 'P46935',
#           'url': 'https://www.uniprot.org/uniprot/P46935'}}]},
#       'topology': {'value': 'Peripheral membrane protein',
#        'evidences': [{'code': 'ECO:0000250',
#          'source': {'name': 'UniProtKB',
#           'id': 'P46935',
#           'url': 'https://www.uniprot.org/uniprot/P46935'}}]}}],
#     'text': [{'value': 'Predominantly cytoplasmic but also located in the nucleus (PubMed:11342538). Recruited to the plasma membrane by GRB10. Once complexed with GRB10 and IGF1R, follows IGF1R internalization, remaining associated with early endosomes. Uncouples from IGF1R-containing endosomes before the sorting of the receptor to the lysosomal compartment (By similarity). May be recruited to exosomes by NDFIP1 (PubMed:18819914)',
#       'evidences': [{'code': 'ECO:0000250',
#         'source': {'name': 'UniProtKB',
#          'id': 'P46935',
#          'url': 'https://www.uniprot.org/uniprot/P46935'}},
#        {'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '11342538',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11342538',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/11342538'}},
#        {'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '18819914',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18819914',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/18819914'}}]}]}]},
#  {'accession': 'P30260',
#   'name': 'CDC27_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
#   'interactions': [{'accession1': 'P30260',
#     'accession2': 'Q9UJX5',
#     'gene': 'ANAPC4',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-2554854',
#     'organismDiffer': False,
#     'experiments': 8},
#    {'accession1': 'P30260',
#     'accession2': 'P24385',
#     'gene': 'CCND1',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-375001',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P30260',
#     'accession2': 'Q12834',
#     'gene': 'CDC20',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-367462',
#     'organismDiffer': False,
#     'experiments': 12},
#    {'accession1': 'P30260',
#     'accession2': 'P12830',
#     'gene': 'CDH1',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-727477',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P30260',
#     'accession2': 'P21964-2',
#     'gene': 'COMT',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-10200977',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P30260',
#     'accession2': 'Q9UKT4',
#     'gene': 'FBXO5',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-852298',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P30260',
#     'accession2': 'O43524',
#     'gene': 'FOXO3',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-1644164',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P30260',
#     'accession2': 'Q9UM11',
#     'gene': 'FZR1',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-724997',
#     'organismDiffer': False,
#     'experiments': 12},
#    {'accession1': 'P30260',
#     'accession2': 'Q13257',
#     'gene': 'MAD2L1',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-78203',
#     'organismDiffer': False,
#     'experiments': 8},
#    {'accession1': 'P30260',
#     'accession2': 'Q9UI95',
#     'gene': 'MAD2L2',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-77889',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P30260',
#     'accession2': 'P16333',
#     'gene': 'NCK1',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-389883',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P30260',
#     'accession2': 'P51955',
#     'gene': 'NEK2',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-633182',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'P30260',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-994813',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': False,
#     'experiments': 7}],
#   'subcellularLocations': [{'type': 'SUBCELLULAR_LOCATION',
#     'locations': [{'location': {'value': 'Nucleus',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '18445686',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18445686',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/18445686'}}]}},
#      {'location': {'value': 'Cytoplasm, cytoskeleton, spindle',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '18445686',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18445686',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/18445686'}}]}}]}]},
#  {'accession': 'O60307',
#   'name': 'MAST3_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
#   'interactions': [{'accession1': 'O60307',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-311420',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': False,
#     'experiments': 3}]},
#  {'accession': 'Q62696',
#   'name': 'DLG1_RAT',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 10116,
#   'interactions': [{'accession1': 'Q62696',
#     'accession2': 'F1MAB7',
#     'gene': 'Dgki',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-8523614',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'Q62696',
#     'accession2': 'O08560',
#     'gene': 'Dgkz',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-8570505',
#     'organismDiffer': False,
#     'experiments': 4},
#    {'accession1': 'Q62696',
#     'accession2': 'P31016',
#     'gene': 'Dlg4',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-375655',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'Q62696',
#     'accession2': 'Q64273',
#     'gene': 'Kcnj2',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-703577',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'Q62696',
#     'accession2': 'Q460M5',
#     'gene': 'Lrfn2',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-877185',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'Q62696',
#     'accession2': 'P34926',
#     'gene': 'Map1a',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-631571',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'Q62696',
#     'accession2': 'Q9Y297',
#     'gene': 'BTRC',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-307461',
#     'organismDiffer': True,
#     'experiments': 3},
#    {'accession1': 'Q62696',
#     'accession2': 'P35347',
#     'gene': 'Crhr1',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-16879653',
#     'organismDiffer': True,
#     'experiments': 3},
#    {'accession1': 'Q62696',
#     'accession2': 'O14490',
#     'gene': 'DLGAP1',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-1753207',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'Q62696',
#     'accession2': 'P89079',
#     'gene': 'E4',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-7401124',
#     'organismDiffer': True,
#     'experiments': 4},
#    {'accession1': 'Q62696',
#     'accession2': 'Q8VDU0',
#     'gene': 'Gpsm2',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-7575403',
#     'organismDiffer': True,
#     'experiments': 7},
#    {'accession1': 'Q62696',
#     'accession2': 'E9Q4K7',
#     'gene': 'Kif13b',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-9085496',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'Q62696',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'Q62696',
#     'accession2': 'B1AYL1',
#     'gene': 'Scn7a',
#     'interactor1': 'EBI-389325',
#     'interactor2': 'EBI-8068354',
#     'organismDiffer': True,
#     'experiments': 3}],
#   'subcellularLocations': [{'type': 'SUBCELLULAR_LOCATION',
#     'locations': [{'location': {'value': 'Membrane',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '19213956',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19213956',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/19213956'}}]},
#       'topology': {'value': 'Peripheral membrane protein',
#        'evidences': [{'code': 'ECO:0000250',
#          'source': {'name': 'UniProtKB',
#           'id': 'Q12959',
#           'url': 'https://www.uniprot.org/uniprot/Q12959'}}]}},
#      {'location': {'value': 'Basolateral cell membrane',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '11865057',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11865057',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/11865057'}}]}},
#      {'location': {'value': 'Endoplasmic reticulum membrane',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '10629225',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/10629225',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/10629225'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '15044483',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15044483',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/15044483'}}]}},
#      {'location': {'value': 'Postsynaptic density',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '15044483',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15044483',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/15044483'}}]}},
#      {'location': {'value': 'Synapse',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '10629225',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/10629225',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/10629225'}}]}},
#      {'location': {'value': 'Cell membrane, sarcolemma',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '19213956',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/19213956',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/19213956'}}]}},
#      {'location': {'value': 'Cell junction',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '17980554',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17980554',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/17980554'}}]}},
#      {'location': {'value': 'Cytoplasm',
#        'evidences': [{'code': 'ECO:0000250',
#          'source': {'name': 'UniProtKB',
#           'id': 'Q12959',
#           'url': 'https://www.uniprot.org/uniprot/Q12959'}}]}},
#      {'location': {'value': 'Apical cell membrane',
#        'evidences': [{'code': 'ECO:0000250',
#          'source': {'name': 'UniProtKB',
#           'id': 'Q12959',
#           'url': 'https://www.uniprot.org/uniprot/Q12959'}}]}}],
#     'text': [{'value': 'Colocalizes with EPB41 at regions of intercellular contacts. Basolateral in epithelial cells (PubMed:11865057). May also associate with endoplasmic reticulum membranes (PubMed:10629225, PubMed:15044483). Mainly found in neurons soma, moderately found at postsynaptic densities (PubMed:15044483)',
#       'evidences': [{'code': 'ECO:0000250',
#         'source': {'name': 'UniProtKB',
#          'id': 'Q12959',
#          'url': 'https://www.uniprot.org/uniprot/Q12959'}},
#        {'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '10629225',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/10629225',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/10629225'}},
#        {'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '11865057',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11865057',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/11865057'}},
#        {'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '15044483',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15044483',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/15044483'}}]}]}]},
#  {'accession': 'Q5T2D3',
#   'name': 'OTUD3_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
# ...
#          'source': {'name': 'PubMed',
#           'id': '11739654',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11739654',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/11739654'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '17965019',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17965019',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/17965019'}}]}},
#      {'location': {'value': 'Nucleus, nucleoplasm',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '11739654',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11739654',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/11739654'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '17965019',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17965019',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/17965019'}}]}},
#      {'location': {'value': 'Nucleus, nucleolus',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '11739654',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/11739654',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/11739654'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '17965019',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17965019',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/17965019'}}]}}],
#     'text': [{'value': 'Primarily nuclear and largely excluded from the nucleolus. Highly mobile in cells and can be relocalized through interaction with targeting subunits. NOM1 plays a role in targeting this protein to the nucleolus. In the presence of PPP1R8 relocalizes from the nucleus to nuclear speckles. Shuttles toward the cytosol during infection with VEEV (PubMed:29769351)',
#       'evidences': [{'code': 'ECO:0000269',
#         'source': {'name': 'PubMed',
#          'id': '29769351',
#          'url': 'http://www.ncbi.nlm.nih.gov/pubmed/29769351',
#          'alternativeUrl': 'https://europepmc.org/abstract/MED/29769351'}}]}]}]},
#  {'accession': 'Q9P0U4',
#   'name': 'CXXC1_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
#   'interactions': [{'accession1': 'Q9P0U4',
#     'accession2': 'P50222',
#     'gene': 'MEOX2',
#     'interactor1': 'EBI-949911',
#     'interactor2': 'EBI-748397',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'Q9P0U4',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-949911',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'Q9P0U4',
#     'accession2': 'Q15291',
#     'gene': 'RBBP5',
#     'interactor1': 'EBI-949911',
#     'interactor2': 'EBI-592823',
#     'organismDiffer': False,
#     'experiments': 6},
#    {'accession1': 'Q9P0U4',
#     'accession2': 'Q86VP1',
#     'gene': 'TAX1BP1',
#     'interactor1': 'EBI-949911',
#     'interactor2': 'EBI-529518',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'Q9P0U4',
#     'accession2': 'P04637',
#     'gene': 'TP53',
#     'interactor1': 'EBI-949911',
#     'interactor2': 'EBI-366083',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'Q9P0U4-2',
#     'accession2': 'Q86VP1',
#     'gene': 'TAX1BP1',
#     'interactor1': 'EBI-12743307',
#     'interactor2': 'EBI-529518',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'Q9P0U4-2',
#     'accession2': 'Q8N4U5',
#     'gene': 'TCP11L2',
#     'interactor1': 'EBI-12743307',
#     'interactor2': 'EBI-11897462',
#     'organismDiffer': False,
#     'experiments': 3}],
#   'subcellularLocations': [{'type': 'SUBCELLULAR_LOCATION',
#     'locations': [{'location': {'value': 'Nucleus speckle',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '12200428',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/12200428',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/12200428'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '17355966',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/17355966',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/17355966'}}]}},
#      {'location': {'value': 'Nucleus',
#        'evidences': [{'code': 'ECO:0000250',
#          'source': {'name': 'UniProtKB',
#           'id': 'Q9CWW7',
#           'url': 'https://www.uniprot.org/uniprot/Q9CWW7'}}]}}],
#     'text': [{'value': 'Associated with euchromatin. During mitosis, excluded from condensed chromosomes'}]}]},
#  {'accession': 'Q9JHL1',
#   'name': 'NHRF2_MOUSE',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 10090,
#   'interactions': [{'accession1': 'Q9JHL1',
#     'accession2': 'P05622',
#     'gene': 'Pdgfrb',
#     'interactor1': 'EBI-538451',
#     'interactor2': 'EBI-1554855',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'Q9JHL1',
#     'accession2': 'O08586',
#     'gene': 'Pten',
#     'interactor1': 'EBI-538451',
#     'interactor2': 'EBI-1186266',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'Q9JHL1',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-538451',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': True,
#     'experiments': 2}],
#   'subcellularLocations': [{'type': 'SUBCELLULAR_LOCATION',
#     'locations': [{'location': {'value': 'Endomembrane system',
#        'evidences': [{'code': 'ECO:0000250'}]},
#       'topology': {'value': 'Peripheral membrane protein',
#        'evidences': [{'code': 'ECO:0000250'}]}},
#      {'location': {'value': 'Nucleus',
#        'evidences': [{'code': 'ECO:0000250'}]}},
#      {'location': {'value': 'Apical cell membrane',
#        'evidences': [{'code': 'ECO:0000250'}]}}],
#     'text': [{'value': 'Localizes with EZR and PODXL at the apical cell membrane of glomerular epithelium cells and the sides of the food processes. Nuclear, in a punctate pattern (By similarity)',
#       'evidences': [{'code': 'ECO:0000250'}]}]}]},
#  {'accession': 'P60484-1',
#   'name': 'PTEN_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
#   'interactions': [{'accession1': 'P60484-1',
#     'accession2': 'Q19T08',
#     'gene': 'ECSCR',
#     'interactor1': 'EBI-15722967',
#     'interactor2': 'EBI-15778214',
#     'organismDiffer': False,
#     'experiments': 4},
#    {'accession1': 'P60484-1',
#     'accession2': 'Q5T2D3',
#     'gene': 'OTUD3',
#     'interactor1': 'EBI-15722967',
#     'interactor2': 'EBI-16170539',
#     'organismDiffer': False,
#     'experiments': 9},
#    {'accession1': 'P60484-1',
#     'accession2': 'P60484-1',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-15722967',
#     'interactor2': 'EBI-15722967',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'P60484-1',
#     'accession2': 'Q93009',
#     'gene': 'USP7',
#     'interactor1': 'EBI-15722967',
#     'interactor2': 'EBI-302474',
#     'organismDiffer': False,
#     'experiments': 5}]},
#  {'accession': 'Q15599',
#   'name': 'NHRF2_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
#   'interactions': [{'accession1': 'Q15599',
#     'accession2': 'P07355',
#     'gene': 'ANXA2',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-352622',
#     'organismDiffer': False,
#     'experiments': 6},
#    {'accession1': 'Q15599',
#     'accession2': 'P13569',
#     'gene': 'CFTR',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-349854',
#     'organismDiffer': False,
#     'experiments': 14},
#    {'accession1': 'Q15599',
#     'accession2': 'Q9Y2H0-1',
#     'gene': 'DLGAP4',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-12000556',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'Q15599',
#     'accession2': 'Q9HBW0',
#     'gene': 'LPAR2',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-765995',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'Q15599',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': False,
#     'experiments': 5},
#    {'accession1': 'Q15599',
#     'accession2': 'P40879',
#     'gene': 'SLC26A3',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-8542350',
#     'organismDiffer': False,
#     'experiments': 5},
#    {'accession1': 'Q15599',
#     'accession2': 'Q15599',
#     'gene': 'SLC9A3R2',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-1149760',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'Q15599',
#     'accession2': 'Q05066',
#     'gene': 'SRY',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-464987',
#     'organismDiffer': False,
#     'experiments': 9},
#    {'accession1': 'Q15599',
#     'accession2': 'Q9BUZ4',
#     'gene': 'TRAF4',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-3650647',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'Q15599',
#     'accession2': 'O00308',
#     'gene': 'WWP2',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-743923',
#     'organismDiffer': False,
#     'experiments': 3},
#    {'accession1': 'Q15599',
#     'accession2': 'P46937',
#     'gene': 'YAP1',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-1044059',
#     'organismDiffer': False,
#     'experiments': 4},
#    {'accession1': 'Q15599',
#     'accession2': 'B7UR60',
#     'gene': 'E2348C_1442',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-25435618',
#     'organismDiffer': True,
#     'experiments': 6},
#    {'accession1': 'Q15599',
#     'accession2': 'B7UMA0',
#     'gene': 'map',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-2529418',
#     'organismDiffer': True,
#     'experiments': 4},
#    {'accession1': 'Q15599',
#     'accession2': 'Q7DB76',
#     'gene': 'map',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-10039068',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'Q15599',
#     'accession2': 'Q9R0W0',
#     'gene': 'mGluR1a',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-8505383',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'Q15599',
#     'accession2': 'Q8X831',
#     'gene': 'nleH1-1',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-16088619',
#     'organismDiffer': True,
#     'experiments': 5},
#    {'accession1': 'Q15599',
#     'accession2': 'P26043',
#     'gene': 'Rdx',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-647737',
#     'organismDiffer': True,
#     'experiments': 2},
#    {'accession1': 'Q15599',
#     'accession2': 'Q05738',
#     'gene': 'Sry',
#     'interactor1': 'EBI-1149760',
#     'interactor2': 'EBI-7820116',
#     'organismDiffer': True,
#     'experiments': 5}],
#   'subcellularLocations': [{'type': 'SUBCELLULAR_LOCATION',
#     'locations': [{'location': {'value': 'Endomembrane system',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '9054412',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9054412',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/9054412'}}]},
#       'topology': {'value': 'Peripheral membrane protein',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '9054412',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9054412',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/9054412'}}]}},
#      {'location': {'value': 'Nucleus',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '9054412',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9054412',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/9054412'}}]}},
#      {'location': {'value': 'Apical cell membrane',
#        'evidences': [{'code': 'ECO:0000250'}]}}],
#     'text': [{'value': 'Localizes with EZR and PODXL at the apical cell membrane of glomerular epithelium cells and the sides of the food processes (By similarity). Nuclear, in a punctate pattern',
#       'evidences': [{'code': 'ECO:0000250'}]}]}]},
#  {'accession': 'O43791',
#   'name': 'SPOP_HUMAN',
#   'proteinExistence': 'Evidence at protein level',
#   'taxonomy': 9606,
#   'interactions': [{'accession1': 'O43791',
#     'accession2': 'Q13618',
#     'gene': 'CUL3',
#     'interactor1': 'EBI-743549',
#     'interactor2': 'EBI-456129',
#     'organismDiffer': False,
#     'experiments': 2},
#    {'accession1': 'O43791',
#     'accession2': 'Q9UER7',
#     'gene': 'DAXX',
#     'interactor1': 'EBI-743549',
#     'interactor2': 'EBI-77321',
#     'organismDiffer': False,
#     'experiments': 5},
#    {'accession1': 'O43791',
#     'accession2': 'Q16829',
#     'gene': 'DUSP7',
#     'interactor1': 'EBI-743549',
#     'interactor2': 'EBI-1265847',
#     'organismDiffer': False,
#     'experiments': 5},
#    {'accession1': 'O43791',
#     'accession2': 'Q99836',
#     'gene': 'MYD88',
#     'interactor1': 'EBI-743549',
#     'interactor2': 'EBI-447677',
#     'organismDiffer': False,
#     'experiments': 7},
#    {'accession1': 'O43791',
#     'accession2': 'Q9Y6Q9',
#     'gene': 'NCOA3',
#     'interactor1': 'EBI-743549',
#     'interactor2': 'EBI-81196',
#     'organismDiffer': False,
#     'experiments': 6},
#    {'accession1': 'O43791',
#     'accession2': 'P60484',
#     'gene': 'PTEN',
#     'interactor1': 'EBI-743549',
#     'interactor2': 'EBI-696162',
#     'organismDiffer': False,
#     'experiments': 4}],
#   'diseases': [{'type': 'DISEASE',
#     'diseaseId': 'Nabais Sa-de Vries syndrome 1',
#     'acronym': 'NSDVS1',
#     'dbReference': {'type': 'MIM', 'id': '618828'},
#     'description': {'value': 'An autosomal dominant disorder characterized by global developmental delay, impaired intellectual development, speech delay, and variable behavioral abnormalities. Affected individuals show congenital microcephaly and dysmorphic facial features, including round face, small palpebral fissures, highly arched eyebrows, and short nose.',
#      'evidences': [{'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '32109420',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/32109420',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/32109420'}}]},
#     'text': [{'value': 'The disease is caused by variants affecting the gene represented in this entry'}]},
#    {'type': 'DISEASE',
#     'diseaseId': 'Nabais Sa-de Vries syndrome 2',
#     'acronym': 'NSDVS2',
#     'dbReference': {'type': 'MIM', 'id': '618829'},
#     'description': {'value': 'An autosomal dominant disorder characterized by global developmental delay apparent from birth, impaired intellectual development, speech delay, dysmorphic facial features, and additional anomalies including congenital heart defects, sleep disturbances, hypotonia, and variable endocrine abnormalities.',
#      'evidences': [{'code': 'ECO:0000269',
#        'source': {'name': 'PubMed',
#         'id': '32109420',
#         'url': 'http://www.ncbi.nlm.nih.gov/pubmed/32109420',
#         'alternativeUrl': 'https://europepmc.org/abstract/MED/32109420'}}]},
#     'text': [{'value': 'The disease is caused by variants affecting distinct genetic loci, including the gene represented in this entry'}]}],
#   'subcellularLocations': [{'type': 'SUBCELLULAR_LOCATION',
#     'locations': [{'location': {'value': 'Nucleus',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '22085717',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/22085717',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/22085717'}}]}},
#      {'location': {'value': 'Nucleus speckle',
#        'evidences': [{'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '15897469',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/15897469',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/15897469'}},
#         {'code': 'ECO:0000269',
#          'source': {'name': 'PubMed',
#           'id': '9414087',
#           'url': 'http://www.ncbi.nlm.nih.gov/pubmed/9414087',
#           'alternativeUrl': 'https://europepmc.org/abstract/MED/9414087'}}]}}]}]}]

# %%
#Select out the genes for humans from json_var_dictionary that interact with PTEN and put them in an array.
###   Your code here  ###
pten_dic = []
for gene in json_var_dictionary:
  if 'PTEN' in gene['name']:
    pten_dic.append(gene)
pten_genes = []
for dic in pten_dic:
  for interaction in dic['interactions']:
    pten_genes.append(interaction['gene'])
print(len(pten_genes))
pten_genes = list(set(pten_genes))
print(len(pten_genes))
pten_genes.sort()
print(pten_genes)
# Out:
# 56
# 25
# ['BMI1', 'CDC27', 'CXXC1', 'DBN1', 'Dlg1', 'ECSCR', 'FRK', 'MAST3', 'Magi2', 'Magi3', 'Mast1', 'Mast2', 'NCOA3', 'NEDD4', 'OTUD3', 'PDGFRB', 'PICK1', 'PPP1CA', 'PRDX1', 'PTEN', 'SLC9A3R1', 'SLC9A3R2', 'SPOP', 'Slc9a3r2', 'USP7']

# %% [markdown]
# It is interesting to look at the interactions that have been found with the PTEN gene. If you notice, CDC27 is on the list of interacting proteins, when we earlier found they had no interaction based on their correlation network. This gives an interesting problem in the world of bioinformatics. You can do a lot of different analyses, but even if you have found something, that does not mean it's completely true or relevant. There can also be factors that are hard to recognize. It could be that the genes correlate regularly, but correlate differently in cancerous tissue. This is a good start to understanding protein-protein interactions, but there is much more to be considered and studied before we get the full picture of cancer.

# %% [markdown]
# ## PRACTICE PROBLEM
#
# 6. Which one of the interacting proteins with PTEN from UniProt shows the highest correlation in our LUAD correlation dataframe, excluding its correlation with itself?

# %%
###       Question 6         ###
#  Which one of the interacting proteins with PTEN from UniProt shows the highest correlation in our LUAD correlation
#  dataframe, excluding its correlation with itself?
#  Your answer should be in the format "gene:correlation value" with the value rounded to 3 decimal places.
#  e.g DBN1:0.736
#  You should derive your answer with coding, not any shortcuts.

###      Your code here      ###
def ptenInteraction(x):
  if x in pten_genes:
    return True
  else:
    return False
max = 0
index = 0
PTEN = lu_correlation['PTEN']
for i in range(len(PTEN)):
  if PTEN.index[i] in pten_genes:
   if abs(PTEN[i]) > abs(max):
     if PTEN[i] != 1:
        max = PTEN[i]
        index = i
answer_6 = PTEN.index[index] + ':' + str(round(PTEN[index], 3))
print(answer_6)
# Out:
# PDGFRB:0.568

# %%
###  Question 6: Submitting the answer   ###
# To submit, your code above should have created a variable 'answer_6'.
result = hw.submit(question = 6, answer = answer_6)
print(result)
# Out:
# True

# %%
### Question 6: Getting help ###
hints = hw.getHint(question=6)
print(hints)
# Out:
# Question 6 hints:
# *A high correlation can be negative or positive.

# %% [markdown]
# # Part 5. Turn it in
# **Congrats!**
#
# Now that you have finished the assignment, use the endSession command to report your score. Once you have completed the notebook, please share it with your instructor.

# %%
hw.endSession()
# Out:
#                       SESSION SUMMARY
# ------------------------------------------------------------
# Student ID:                                          joeaman
# Homework:                                         bio462_hw6
# ------------------------------------------------------------
#   Question  |  Correct  |  Attempts  |        Answer
#      1      |    Yes    |     2      |   MSH6
#      2      |    Yes    |     5      |   HNSCC_5755, LSCC_5536, LUAD_4832
#      3      |    Yes    |     3      |   692
#      4      |    Yes    |     2      |   496
#      5      |    Yes    |     5      |   ACP5, ACVRL1, AGER, AKAP2, ALAD, ALDH1A1, ALOX5, ANK1, ARHGAP31, ARHGAP6, ARL8B, ARRB1, BLVRB, BPGM, CA1, CA4, CALCRL, CALM3, CASKIN2, CAT, CAVIN2, CCDC22, CES1, CES1, CLIC2, CYP27A1, DDI2, DMTN, DMTN, DMXL1, DOCK9, EHD2, EPB41, EPB42, ESAM, FBP1, FBXO7, GCHFR, GFOD1, GMPR, GNB2, GNG11, GPD1, GRASP, GYPA, GYPC, HAGH, HBA2, HBB, HBD, HBZ, HPCAL1, HSPA12B, HYI, IDS, JMJD7, KEL, LAMTOR3, MPP1, MRAS, MVB12B, NEBL, NEBL, NIPSNAP3A, OSBPL1A, PCMT1, PITHD1, PKLR, PLLP, PRAMEF12, PRDX2, PRX, QKI, RAD23A, RASSF8, RILP, RNF123, RNF13, ROGDI, RPIA, RSU1, SHANK3, SLC39A10, SLC4A1, SNCA, SPG11, SPTA1, STARD13, STX11, STXBP6, SULT1A1, SULT1A2, TANGO2, TAS1R3, TBCEL, THBD, TNNC1, TRPV2, TTLL4, UBAC1, VAT1, VIPR1, VPS26C, ZBTB39
#      6      |    Yes    |     3      |   PDGFRB:0.568
# ------------------------------------------------------------
# Total Score: 6/6 = 100.00%
